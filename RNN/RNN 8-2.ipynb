# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# Read data from CSV file
df = pd.read_csv("ACB.VN.csv")
df.dropna(inplace=True)

# %%
# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Set the 'Date' column as the index value
df.set_index('Date', inplace=True)

# Select 'Close' column
data = df['Close'].values

# %%
# Scale data
scaler = MinMaxScaler(feature_range=(0,1))
data_scaled = scaler.fit_transform(data.reshape(-1, 1))

# Define the size of train and test set
train_size = int(len(data_scaled) * 0.8)
test_size = len(data_scaled) - train_size

# Split the data into train and test set
train_data = data_scaled[:train_size]
test_data = data_scaled[train_size:]

def add_data(data, sequence_length=1):
    X, Y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i : (i + sequence_length), 0])
        Y.append(data[i + sequence_length, 0])
    return np.array(X), np.array(Y)

# Reshape into X=t,t+1,t+2..t+60 and Y=t+60
sequence_length = 60

X_train, y_train = add_data(train_data, sequence_length)
X_test, y_test = add_data(test_data, sequence_length)

# %%
# Reshape input data for RNN
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build RNN model
model = Sequential()
model.add(SimpleRNN(50, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Fit the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=2, validation_data=(X_test, y_test))

# Predict Close price for the next 30, 60, 90 days
def predict_next_days(n_days, model, last_sequence):
    y_next_days = []
    for i in range(n_days):
        next_day_pred = model.predict(last_sequence)
        y_next_days.append(next_day_pred[0][0])
        last_sequence = np.concatenate([last_sequence[:, 1:, :], next_day_pred.reshape(1, 1, 1)], axis=1)
    return scaler.inverse_transform(np.array(y_next_days).reshape(-1, 1))

last_sequence_days = data_scaled[-sequence_length:].reshape(1, sequence_length, 1)

y_next_30_days = predict_next_days(30, model, last_sequence_days)
y_next_60_days = predict_next_days(60, model, last_sequence_days)
y_next_90_days = predict_next_days(90, model, last_sequence_days)
# Out:
# Epoch 1/50
# 31/31 - 2s - loss: 0.0565 - val_loss: 0.0060 - 2s/epoch - 72ms/step
# Epoch 2/50
# 31/31 - 0s - loss: 0.0015 - val_loss: 0.0048 - 403ms/epoch - 13ms/step
# Epoch 3/50
# 31/31 - 0s - loss: 0.0011 - val_loss: 0.0042 - 406ms/epoch - 13ms/step
# Epoch 4/50
# 31/31 - 0s - loss: 0.0010 - val_loss: 0.0046 - 400ms/epoch - 13ms/step
# Epoch 5/50
# 31/31 - 0s - loss: 0.0010 - val_loss: 0.0043 - 416ms/epoch - 13ms/step
# Epoch 6/50
# 31/31 - 0s - loss: 9.7630e-04 - val_loss: 0.0036 - 412ms/epoch - 13ms/step
# Epoch 7/50
# 31/31 - 1s - loss: 9.5510e-04 - val_loss: 0.0025 - 559ms/epoch - 18ms/step
# Epoch 8/50
# 31/31 - 1s - loss: 0.0011 - val_loss: 0.0028 - 658ms/epoch - 21ms/step
# Epoch 9/50
# 31/31 - 1s - loss: 9.6943e-04 - val_loss: 0.0029 - 674ms/epoch - 22ms/step
# Epoch 10/50
# 31/31 - 1s - loss: 9.4325e-04 - val_loss: 0.0031 - 700ms/epoch - 23ms/step
# Epoch 11/50
# 31/31 - 1s - loss: 8.3965e-04 - val_loss: 0.0025 - 700ms/epoch - 23ms/step
# Epoch 12/50
# 31/31 - 1s - loss: 8.1697e-04 - val_loss: 0.0037 - 700ms/epoch - 23ms/step
# Epoch 13/50
# 31/31 - 1s - loss: 8.4077e-04 - val_loss: 0.0032 - 575ms/epoch - 19ms/step
# Epoch 14/50
# 31/31 - 0s - loss: 7.8023e-04 - val_loss: 0.0024 - 411ms/epoch - 13ms/step
# Epoch 15/50
# 31/31 - 0s - loss: 7.5926e-04 - val_loss: 0.0020 - 431ms/epoch - 14ms/step
# Epoch 16/50
# 31/31 - 0s - loss: 8.1464e-04 - val_loss: 0.0014 - 435ms/epoch - 14ms/step
# Epoch 17/50
# 31/31 - 0s - loss: 8.2380e-04 - val_loss: 0.0013 - 404ms/epoch - 13ms/step
# Epoch 18/50
# 31/31 - 0s - loss: 7.2724e-04 - val_loss: 0.0023 - 426ms/epoch - 14ms/step
# Epoch 19/50
# 31/31 - 0s - loss: 8.6147e-04 - val_loss: 0.0016 - 408ms/epoch - 13ms/step
# Epoch 20/50
# 31/31 - 0s - loss: 7.5130e-04 - val_loss: 0.0022 - 408ms/epoch - 13ms/step
# Epoch 21/50
# 31/31 - 0s - loss: 6.9975e-04 - val_loss: 0.0023 - 431ms/epoch - 14ms/step
# Epoch 22/50
# 31/31 - 0s - loss: 6.7382e-04 - val_loss: 0.0018 - 397ms/epoch - 13ms/step
# Epoch 23/50
# 31/31 - 0s - loss: 6.3111e-04 - val_loss: 0.0024 - 430ms/epoch - 14ms/step
# Epoch 24/50
# 31/31 - 0s - loss: 6.6698e-04 - val_loss: 0.0014 - 402ms/epoch - 13ms/step
# Epoch 25/50
# 31/31 - 0s - loss: 6.7072e-04 - val_loss: 0.0016 - 412ms/epoch - 13ms/step
# Epoch 26/50
# 31/31 - 0s - loss: 6.7147e-04 - val_loss: 0.0022 - 427ms/epoch - 14ms/step
# Epoch 27/50
# 31/31 - 0s - loss: 7.0060e-04 - val_loss: 0.0011 - 412ms/epoch - 13ms/step
# Epoch 28/50
# 31/31 - 0s - loss: 5.7722e-04 - val_loss: 0.0012 - 430ms/epoch - 14ms/step
# Epoch 29/50
# 31/31 - 0s - loss: 6.0110e-04 - val_loss: 0.0018 - 397ms/epoch - 13ms/step
# Epoch 30/50
# 31/31 - 0s - loss: 6.1311e-04 - val_loss: 0.0017 - 460ms/epoch - 15ms/step
# Epoch 31/50
# 31/31 - 0s - loss: 5.4956e-04 - val_loss: 8.3503e-04 - 412ms/epoch - 13ms/step
# Epoch 32/50
# 31/31 - 0s - loss: 5.3854e-04 - val_loss: 8.6386e-04 - 431ms/epoch - 14ms/step
# Epoch 33/50
# 31/31 - 0s - loss: 6.0590e-04 - val_loss: 0.0010 - 440ms/epoch - 14ms/step
# Epoch 34/50
# 31/31 - 0s - loss: 5.6950e-04 - val_loss: 8.2559e-04 - 412ms/epoch - 13ms/step
# Epoch 35/50
# 31/31 - 0s - loss: 5.3651e-04 - val_loss: 0.0014 - 452ms/epoch - 15ms/step
# Epoch 36/50
# 31/31 - 0s - loss: 5.3740e-04 - val_loss: 8.8968e-04 - 434ms/epoch - 14ms/step
# Epoch 37/50
# 31/31 - 1s - loss: 5.8018e-04 - val_loss: 7.4643e-04 - 729ms/epoch - 24ms/step
# Epoch 38/50
# 31/31 - 1s - loss: 5.8151e-04 - val_loss: 0.0015 - 677ms/epoch - 22ms/step
# Epoch 39/50
# 31/31 - 1s - loss: 5.2908e-04 - val_loss: 0.0016 - 633ms/epoch - 20ms/step
# Epoch 40/50
# 31/31 - 1s - loss: 4.9096e-04 - val_loss: 9.0201e-04 - 727ms/epoch - 23ms/step
# Epoch 41/50
# 31/31 - 1s - loss: 5.3055e-04 - val_loss: 0.0015 - 685ms/epoch - 22ms/step
# Epoch 42/50
# 31/31 - 1s - loss: 4.9909e-04 - val_loss: 0.0012 - 624ms/epoch - 20ms/step
# Epoch 43/50
# 31/31 - 0s - loss: 4.6093e-04 - val_loss: 0.0013 - 446ms/epoch - 14ms/step
# Epoch 44/50
# 31/31 - 0s - loss: 4.5661e-04 - val_loss: 5.9608e-04 - 440ms/epoch - 14ms/step
# Epoch 45/50
# 31/31 - 0s - loss: 4.5603e-04 - val_loss: 5.4524e-04 - 446ms/epoch - 14ms/step
# Epoch 46/50
# 31/31 - 0s - loss: 5.3523e-04 - val_loss: 8.9268e-04 - 431ms/epoch - 14ms/step
# Epoch 47/50
# 31/31 - 0s - loss: 4.6352e-04 - val_loss: 0.0015 - 440ms/epoch - 14ms/step
# Epoch 48/50
# 31/31 - 0s - loss: 4.5316e-04 - val_loss: 0.0010 - 453ms/epoch - 15ms/step
# Epoch 49/50
# 31/31 - 0s - loss: 4.3595e-04 - val_loss: 7.8043e-04 - 415ms/epoch - 13ms/step
# Epoch 50/50
# 31/31 - 0s - loss: 4.7036e-04 - val_loss: 5.2879e-04 - 437ms/epoch - 14ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
# Evaluate model
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_squared_log_error,mean_absolute_error

# Predictions on test set
y_pred_test = model.predict(X_test)
y_pred_82=scaler.inverse_transform(y_pred_test)
# Calculate test metrics
test_mape = mean_absolute_percentage_error(y_test, y_pred_test)
test_mse = mean_squared_error(y_test, y_pred_82)
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(y_test, y_pred_82)

print(f"MAPE on Test set: {test_mape}")
print(f"RMSE on Test set: {test_rmse}")
print(f"MAE on Test set: {test_mae}")
# Out:
# 7/7 [==============================] - 0s 7ms/step
# MAPE on Test set: 0.023695013923708666
# RMSE on Test set: 21701.76668220388
# MAE on Test set: 21614.88842548368

# %%
# Plotting
plt.figure(figsize=(12, 5))

# Train set
plt.plot(df.index[:train_size], scaler.inverse_transform(train_data))

# Test set
plt.plot(df.index[train_size:train_size + len(test_data)], scaler.inverse_transform(test_data))

# Predictions on test set
test_pred_index = df.index[train_size + sequence_length - 1:train_size + len(y_test) + sequence_length - 1]
plt.plot(test_pred_index, scaler.inverse_transform(y_pred_test))

# Predictions for the next 30, 60, 90 days
last_date = df.index[-1]
next_date = last_date + pd.DateOffset(days=1)
index_next_30_days = pd.date_range(start=next_date, periods=30)
index_next_60_days = pd.date_range(start=next_date, periods=60)
index_next_90_days = pd.date_range(start=next_date, periods=90)

plt.plot(index_next_30_days, y_next_30_days, label="Next 30 days")
plt.plot(index_next_60_days, y_next_60_days, label="Next 60 days")
plt.plot(index_next_90_days, y_next_90_days, label="Next 90 days")

plt.legend(['Train', 'Test', 'Predict Test', 'Predict 30 days', 'Predict 60 days', 'Predict 90 days'])
plt.grid()
plt.title("CTG's Stock Price Data With RNN Predictions")
plt.xlabel("Date")
plt.ylabel("Close value")
plt.show()

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# Read data from CSV file
df = pd.read_csv("ACB.VN.csv")
df.dropna(inplace=True)

# %%
# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Set the 'Date' column as the index value
df.set_index('Date', inplace=True)

# Select 'Close' column
data = df['Close'].values

# %%
# Scale data
scaler = MinMaxScaler(feature_range=(0,1))
data_scaled = scaler.fit_transform(data.reshape(-1, 1))

# Define the size of train and test set
train_size = int(len(data_scaled) * 0.7)
test_size = len(data_scaled) - train_size

# Split the data into train and test set
train_data = data_scaled[:train_size]
test_data = data_scaled[train_size:]

def add_data(data, sequence_length=1):
    X, Y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i : (i + sequence_length), 0])
        Y.append(data[i + sequence_length, 0])
    return np.array(X), np.array(Y)

# Reshape into X=t,t+1,t+2..t+60 and Y=t+60
sequence_length = 60

X_train, y_train = add_data(train_data, sequence_length)
X_test, y_test = add_data(test_data, sequence_length)

# %%
# Reshape input data for RNN
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build RNN model
model = Sequential()
model.add(SimpleRNN(50, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Fit the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=2, validation_data=(X_test, y_test))

# Predict Close price for the next 30, 60, 90 days
def predict_next_days(n_days, model, last_sequence):
    y_next_days = []
    for i in range(n_days):
        next_day_pred = model.predict(last_sequence)
        y_next_days.append(next_day_pred[0][0])
        last_sequence = np.concatenate([last_sequence[:, 1:, :], next_day_pred.reshape(1, 1, 1)], axis=1)
    return scaler.inverse_transform(np.array(y_next_days).reshape(-1, 1))

last_sequence_days = data_scaled[-sequence_length:].reshape(1, sequence_length, 1)

y_next_30_days = predict_next_days(30, model, last_sequence_days)
y_next_60_days = predict_next_days(60, model, last_sequence_days)
y_next_90_days = predict_next_days(90, model, last_sequence_days)
# Out:
# Epoch 1/50
# 27/27 - 2s - loss: 0.0339 - val_loss: 0.0126 - 2s/epoch - 63ms/step
# Epoch 2/50
# 27/27 - 0s - loss: 0.0017 - val_loss: 0.0036 - 328ms/epoch - 12ms/step
# Epoch 3/50
# 27/27 - 0s - loss: 0.0011 - val_loss: 0.0034 - 333ms/epoch - 12ms/step
# Epoch 4/50
# 27/27 - 0s - loss: 0.0010 - val_loss: 0.0019 - 336ms/epoch - 12ms/step
# Epoch 5/50
# 27/27 - 0s - loss: 8.8853e-04 - val_loss: 0.0018 - 329ms/epoch - 12ms/step
# Epoch 6/50
# 27/27 - 0s - loss: 8.3582e-04 - val_loss: 0.0011 - 326ms/epoch - 12ms/step
# Epoch 7/50
# 27/27 - 0s - loss: 7.9047e-04 - val_loss: 0.0012 - 327ms/epoch - 12ms/step
# Epoch 8/50
# 27/27 - 0s - loss: 7.6021e-04 - val_loss: 9.5615e-04 - 341ms/epoch - 13ms/step
# Epoch 9/50
# 27/27 - 0s - loss: 7.7239e-04 - val_loss: 0.0015 - 326ms/epoch - 12ms/step
# Epoch 10/50
# 27/27 - 0s - loss: 8.5540e-04 - val_loss: 0.0012 - 339ms/epoch - 13ms/step
# Epoch 11/50
# 27/27 - 0s - loss: 7.0322e-04 - val_loss: 8.8371e-04 - 336ms/epoch - 12ms/step
# Epoch 12/50
# 27/27 - 0s - loss: 7.9554e-04 - val_loss: 9.8847e-04 - 320ms/epoch - 12ms/step
# Epoch 13/50
# 27/27 - 0s - loss: 8.3722e-04 - val_loss: 0.0015 - 337ms/epoch - 12ms/step
# Epoch 14/50
# 27/27 - 0s - loss: 6.2098e-04 - val_loss: 0.0011 - 322ms/epoch - 12ms/step
# Epoch 15/50
# 27/27 - 0s - loss: 6.2369e-04 - val_loss: 8.3010e-04 - 328ms/epoch - 12ms/step
# Epoch 16/50
# 27/27 - 0s - loss: 5.9238e-04 - val_loss: 0.0013 - 336ms/epoch - 12ms/step
# Epoch 17/50
# 27/27 - 0s - loss: 6.6762e-04 - val_loss: 7.4069e-04 - 342ms/epoch - 13ms/step
# Epoch 18/50
# 27/27 - 0s - loss: 5.9492e-04 - val_loss: 7.9980e-04 - 353ms/epoch - 13ms/step
# Epoch 19/50
# 27/27 - 0s - loss: 5.9956e-04 - val_loss: 5.9769e-04 - 358ms/epoch - 13ms/step
# Epoch 20/50
# 27/27 - 0s - loss: 5.6990e-04 - val_loss: 7.0696e-04 - 493ms/epoch - 18ms/step
# Epoch 21/50
# 27/27 - 1s - loss: 5.7834e-04 - val_loss: 6.6656e-04 - 532ms/epoch - 20ms/step
# Epoch 22/50
# 27/27 - 1s - loss: 5.7883e-04 - val_loss: 5.3114e-04 - 502ms/epoch - 19ms/step
# Epoch 23/50
# 27/27 - 1s - loss: 5.2529e-04 - val_loss: 5.6894e-04 - 549ms/epoch - 20ms/step
# Epoch 24/50
# 27/27 - 1s - loss: 6.2000e-04 - val_loss: 5.8839e-04 - 609ms/epoch - 23ms/step
# Epoch 25/50
# 27/27 - 1s - loss: 5.7673e-04 - val_loss: 5.3620e-04 - 629ms/epoch - 23ms/step
# Epoch 26/50
# 27/27 - 0s - loss: 5.8383e-04 - val_loss: 5.5816e-04 - 342ms/epoch - 13ms/step
# Epoch 27/50
# 27/27 - 0s - loss: 4.9225e-04 - val_loss: 6.4300e-04 - 335ms/epoch - 12ms/step
# Epoch 28/50
# 27/27 - 0s - loss: 5.0546e-04 - val_loss: 5.7397e-04 - 360ms/epoch - 13ms/step
# Epoch 29/50
# 27/27 - 0s - loss: 5.3085e-04 - val_loss: 7.1058e-04 - 325ms/epoch - 12ms/step
# Epoch 30/50
# 27/27 - 0s - loss: 4.8393e-04 - val_loss: 5.6246e-04 - 323ms/epoch - 12ms/step
# Epoch 31/50
# 27/27 - 0s - loss: 4.6989e-04 - val_loss: 5.5434e-04 - 355ms/epoch - 13ms/step
# Epoch 32/50
# 27/27 - 0s - loss: 4.7390e-04 - val_loss: 7.0060e-04 - 323ms/epoch - 12ms/step
# Epoch 33/50
# 27/27 - 0s - loss: 4.6889e-04 - val_loss: 6.5425e-04 - 319ms/epoch - 12ms/step
# Epoch 34/50
# 27/27 - 0s - loss: 4.3303e-04 - val_loss: 5.3258e-04 - 345ms/epoch - 13ms/step
# Epoch 35/50
# 27/27 - 0s - loss: 4.3584e-04 - val_loss: 6.0930e-04 - 323ms/epoch - 12ms/step
# Epoch 36/50
# 27/27 - 0s - loss: 5.1154e-04 - val_loss: 4.5784e-04 - 321ms/epoch - 12ms/step
# Epoch 37/50
# 27/27 - 0s - loss: 5.1170e-04 - val_loss: 5.0181e-04 - 353ms/epoch - 13ms/step
# Epoch 38/50
# 27/27 - 0s - loss: 4.6805e-04 - val_loss: 6.1686e-04 - 335ms/epoch - 12ms/step
# Epoch 39/50
# 27/27 - 0s - loss: 4.2325e-04 - val_loss: 4.7688e-04 - 332ms/epoch - 12ms/step
# Epoch 40/50
# 27/27 - 0s - loss: 4.3949e-04 - val_loss: 4.5787e-04 - 353ms/epoch - 13ms/step
# Epoch 41/50
# 27/27 - 0s - loss: 4.3739e-04 - val_loss: 4.1857e-04 - 342ms/epoch - 13ms/step
# Epoch 42/50
# 27/27 - 0s - loss: 4.5334e-04 - val_loss: 4.1703e-04 - 334ms/epoch - 12ms/step
# Epoch 43/50
# 27/27 - 0s - loss: 4.1844e-04 - val_loss: 5.9473e-04 - 352ms/epoch - 13ms/step
# Epoch 44/50
# 27/27 - 0s - loss: 4.4771e-04 - val_loss: 3.9583e-04 - 325ms/epoch - 12ms/step
# Epoch 45/50
# 27/27 - 0s - loss: 4.6632e-04 - val_loss: 6.2368e-04 - 329ms/epoch - 12ms/step
# Epoch 46/50
# 27/27 - 0s - loss: 4.0794e-04 - val_loss: 4.5118e-04 - 338ms/epoch - 13ms/step
# Epoch 47/50
# 27/27 - 0s - loss: 4.8936e-04 - val_loss: 7.8908e-04 - 327ms/epoch - 12ms/step
# Epoch 48/50
# 27/27 - 0s - loss: 5.6334e-04 - val_loss: 4.2262e-04 - 333ms/epoch - 12ms/step
# Epoch 49/50
# 27/27 - 0s - loss: 6.2251e-04 - val_loss: 6.2293e-04 - 342ms/epoch - 13ms/step
# Epoch 50/50
# 27/27 - 0s - loss: 4.5200e-04 - val_loss: 3.9573e-04 - 329ms/epoch - 12ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step

# %%
# Evaluate model
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_squared_log_error,mean_absolute_error

# Predictions on test set
y_pred_test = model.predict(X_test)
y_pred_73=scaler.inverse_transform(y_pred_test)
# Calculate test metrics
test_mape = mean_absolute_percentage_error(y_test, y_pred_test)
test_mse = mean_squared_error(y_test, y_pred_73)
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(y_test, y_pred_73)

print(f"MAPE on Test set: {test_mape}")
print(f"RMSE on Test set: {test_rmse}")
print(f"MAE on Test set: {test_mae}")
# Out:
# 11/11 [==============================] - 0s 7ms/step
# MAPE on Test set: 0.020055904793685846
# RMSE on Test set: 20638.49554916882
# MAE on Test set: 20543.83395884231

# %%
# Plotting
plt.figure(figsize=(12, 5))

# Train set
plt.plot(df.index[:train_size], scaler.inverse_transform(train_data))

# Test set
plt.plot(df.index[train_size:train_size + len(test_data)], scaler.inverse_transform(test_data))

# Predictions on test set
test_pred_index = df.index[train_size + sequence_length - 1:train_size + len(y_test) + sequence_length - 1]
plt.plot(test_pred_index, scaler.inverse_transform(y_pred_test))

# Predictions for the next 30, 60, 90 days
last_date = df.index[-1]
next_date = last_date + pd.DateOffset(days=1)
index_next_30_days = pd.date_range(start=next_date, periods=30)
index_next_60_days = pd.date_range(start=next_date, periods=60)
index_next_90_days = pd.date_range(start=next_date, periods=90)

plt.plot(index_next_30_days, y_next_30_days, label="Next 30 days")
plt.plot(index_next_60_days, y_next_60_days, label="Next 60 days")
plt.plot(index_next_90_days, y_next_90_days, label="Next 90 days")

plt.legend(['Train', 'Test', 'Predict Test', 'Predict 30 days', 'Predict 60 days', 'Predict 90 days'])
plt.grid()
plt.title("ACB's Stock Price Data With RNN Predictions")
plt.xlabel("Date")
plt.ylabel("Close value")
plt.show()

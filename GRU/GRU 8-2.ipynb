# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Input
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_squared_log_error

# %%
# Load and preprocess the data
df = pd.read_csv("ACB.VN.csv")
df.dropna(inplace=True)

# %%
# Convert the time column to datetime
df['Date'] = pd.to_datetime(df['Date'])
# Select column 'Close' as the dependent variable
df_Close = df[['Date', 'Close']]
# Reset the index of the DataFrame
df_Close = df_Close.reset_index(drop=True)

# %%
# Scaler data
scaler = MinMaxScaler(feature_range=(0, 1))
df_Close['Close'] = scaler.fit_transform(np.array(df_Close['Close']).reshape(-1, 1))

# Split train, test set
train_size = int(0.8 * len(df_Close))
test_size = len(df_Close) - train_size

train_data = df_Close[:train_size]
test_data = df_Close[train_size:]

# %%
# Function to create dataset
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)
# Reshape data

time_step = 100
X_train, y_train = create_dataset(train_data[['Close']].values, time_step)
X_test, y_test = create_dataset(test_data[['Close']].values, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Define GRU model
model = Sequential()
model.add(Input(shape=(time_step, 1)))
model.add(GRU(64))
model.add(Dense(1))

# Compile model
model.compile(optimizer='adam', loss='mean_squared_error')

# Fit model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 5s 129ms/step - loss: 0.1320 - val_loss: 0.0225
# Epoch 2/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0180 - val_loss: 0.0093
# Epoch 3/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0088 - val_loss: 0.0175
# Epoch 4/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 5/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 6/100
# 15/15 [==============================] - 1s 49ms/step - loss: 9.2908e-04 - val_loss: 5.3834e-04
# Epoch 7/100
# 15/15 [==============================] - 1s 51ms/step - loss: 6.6483e-04 - val_loss: 5.4718e-04
# Epoch 8/100
# 15/15 [==============================] - 1s 52ms/step - loss: 6.4729e-04 - val_loss: 5.4319e-04
# Epoch 9/100
# 15/15 [==============================] - 1s 52ms/step - loss: 6.3203e-04 - val_loss: 5.0868e-04
# Epoch 10/100
# 15/15 [==============================] - 1s 49ms/step - loss: 6.1516e-04 - val_loss: 4.9601e-04
# Epoch 11/100
# 15/15 [==============================] - 1s 53ms/step - loss: 6.0353e-04 - val_loss: 4.8528e-04
# Epoch 12/100
# 15/15 [==============================] - 1s 52ms/step - loss: 5.9008e-04 - val_loss: 4.7521e-04
# Epoch 13/100
# 15/15 [==============================] - 1s 52ms/step - loss: 5.8241e-04 - val_loss: 4.6759e-04
# Epoch 14/100
# 15/15 [==============================] - 1s 50ms/step - loss: 5.7255e-04 - val_loss: 4.5620e-04
# Epoch 15/100
# 15/15 [==============================] - 1s 82ms/step - loss: 5.6427e-04 - val_loss: 4.4427e-04
# Epoch 16/100
# 15/15 [==============================] - 1s 80ms/step - loss: 5.5306e-04 - val_loss: 4.5123e-04
# Epoch 17/100
# 15/15 [==============================] - 1s 86ms/step - loss: 5.4443e-04 - val_loss: 4.3407e-04
# Epoch 18/100
# 15/15 [==============================] - 1s 51ms/step - loss: 5.3462e-04 - val_loss: 4.4793e-04
# Epoch 19/100
# 15/15 [==============================] - 1s 51ms/step - loss: 5.2922e-04 - val_loss: 4.3502e-04
# Epoch 20/100
# 15/15 [==============================] - 1s 50ms/step - loss: 5.2748e-04 - val_loss: 4.1248e-04
# Epoch 21/100
# 15/15 [==============================] - 1s 52ms/step - loss: 5.1408e-04 - val_loss: 4.0465e-04
# Epoch 22/100
# 15/15 [==============================] - 1s 51ms/step - loss: 5.0742e-04 - val_loss: 4.1386e-04
# Epoch 23/100
# 15/15 [==============================] - 1s 50ms/step - loss: 5.0246e-04 - val_loss: 4.6384e-04
# Epoch 24/100
# 15/15 [==============================] - 1s 50ms/step - loss: 4.9877e-04 - val_loss: 4.4509e-04
# Epoch 25/100
# 15/15 [==============================] - 1s 51ms/step - loss: 4.8723e-04 - val_loss: 3.8032e-04
# Epoch 26/100
# 15/15 [==============================] - 1s 52ms/step - loss: 4.8267e-04 - val_loss: 3.8304e-04
# Epoch 27/100
# 15/15 [==============================] - 1s 50ms/step - loss: 4.7671e-04 - val_loss: 3.7333e-04
# Epoch 28/100
# 15/15 [==============================] - 1s 51ms/step - loss: 4.7024e-04 - val_loss: 3.8336e-04
# Epoch 29/100
# 15/15 [==============================] - 1s 49ms/step - loss: 4.6476e-04 - val_loss: 3.6495e-04
# Epoch 30/100
# 15/15 [==============================] - 1s 52ms/step - loss: 4.7425e-04 - val_loss: 3.6263e-04
# Epoch 31/100
# 15/15 [==============================] - 1s 82ms/step - loss: 4.5729e-04 - val_loss: 3.5801e-04
# Epoch 32/100
# 15/15 [==============================] - 1s 84ms/step - loss: 4.5396e-04 - val_loss: 3.9177e-04
# Epoch 33/100
# 15/15 [==============================] - 1s 91ms/step - loss: 4.4684e-04 - val_loss: 3.6528e-04
# Epoch 34/100
# 15/15 [==============================] - 1s 52ms/step - loss: 4.4666e-04 - val_loss: 3.4815e-04
# Epoch 35/100
# 15/15 [==============================] - 1s 50ms/step - loss: 4.5716e-04 - val_loss: 3.6443e-04
# Epoch 36/100
# 15/15 [==============================] - 1s 51ms/step - loss: 4.5194e-04 - val_loss: 3.4594e-04
# Epoch 37/100
# 15/15 [==============================] - 1s 51ms/step - loss: 4.3475e-04 - val_loss: 3.6369e-04
# Epoch 38/100
# 15/15 [==============================] - 1s 51ms/step - loss: 4.3239e-04 - val_loss: 3.7021e-04
# Epoch 39/100
# 15/15 [==============================] - 1s 51ms/step - loss: 4.3075e-04 - val_loss: 4.4567e-04
# Epoch 40/100
# 15/15 [==============================] - 1s 50ms/step - loss: 4.2660e-04 - val_loss: 3.6212e-04
# Epoch 41/100
# 15/15 [==============================] - 1s 50ms/step - loss: 4.1949e-04 - val_loss: 3.5645e-04
# Epoch 42/100
# 15/15 [==============================] - 1s 51ms/step - loss: 4.1954e-04 - val_loss: 4.1344e-04
# Epoch 43/100
# 15/15 [==============================] - 1s 49ms/step - loss: 4.1773e-04 - val_loss: 4.0468e-04
# Epoch 44/100
# 15/15 [==============================] - 1s 49ms/step - loss: 4.1408e-04 - val_loss: 3.9212e-04
# Epoch 45/100
# 15/15 [==============================] - 1s 52ms/step - loss: 4.0883e-04 - val_loss: 3.6439e-04
# Epoch 46/100
# 15/15 [==============================] - 1s 52ms/step - loss: 4.1018e-04 - val_loss: 4.6342e-04
# Epoch 47/100
# 15/15 [==============================] - 1s 81ms/step - loss: 4.0929e-04 - val_loss: 3.9347e-04
# Epoch 48/100
# 15/15 [==============================] - 1s 84ms/step - loss: 4.0441e-04 - val_loss: 4.5873e-04
# Epoch 49/100
# 15/15 [==============================] - 1s 86ms/step - loss: 4.1219e-04 - val_loss: 4.6768e-04
# Epoch 50/100
# 15/15 [==============================] - 1s 50ms/step - loss: 4.0272e-04 - val_loss: 5.7062e-04
# Epoch 51/100
# 15/15 [==============================] - 1s 52ms/step - loss: 4.1051e-04 - val_loss: 5.0167e-04
# Epoch 52/100
# 15/15 [==============================] - 1s 52ms/step - loss: 3.9469e-04 - val_loss: 3.5931e-04
# Epoch 53/100
# 15/15 [==============================] - 1s 51ms/step - loss: 3.8944e-04 - val_loss: 3.6183e-04
# Epoch 54/100
# 15/15 [==============================] - 1s 51ms/step - loss: 3.8723e-04 - val_loss: 3.5449e-04
# Epoch 55/100
# 15/15 [==============================] - 1s 54ms/step - loss: 3.8294e-04 - val_loss: 4.9726e-04
# Epoch 56/100
# 15/15 [==============================] - 1s 51ms/step - loss: 3.8700e-04 - val_loss: 3.7497e-04
# Epoch 57/100
# 15/15 [==============================] - 1s 50ms/step - loss: 3.9046e-04 - val_loss: 4.0554e-04
# Epoch 58/100
# 15/15 [==============================] - 1s 49ms/step - loss: 3.7949e-04 - val_loss: 3.3421e-04
# Epoch 59/100
# 15/15 [==============================] - 1s 51ms/step - loss: 3.8016e-04 - val_loss: 3.2481e-04
# Epoch 60/100
# 15/15 [==============================] - 1s 52ms/step - loss: 3.8133e-04 - val_loss: 3.4907e-04
# Epoch 61/100
# 15/15 [==============================] - 1s 51ms/step - loss: 3.8023e-04 - val_loss: 3.5497e-04
# Epoch 62/100
# 15/15 [==============================] - 1s 55ms/step - loss: 3.8274e-04 - val_loss: 4.1533e-04
# Epoch 63/100
# 15/15 [==============================] - 1s 82ms/step - loss: 3.7773e-04 - val_loss: 4.6006e-04
# Epoch 64/100
# 15/15 [==============================] - 1s 84ms/step - loss: 3.7286e-04 - val_loss: 4.5107e-04
# Epoch 65/100
# 15/15 [==============================] - 1s 88ms/step - loss: 3.7595e-04 - val_loss: 4.1180e-04
# Epoch 66/100
# 15/15 [==============================] - 1s 50ms/step - loss: 3.7375e-04 - val_loss: 3.4734e-04
# Epoch 67/100
# 15/15 [==============================] - 1s 52ms/step - loss: 3.7486e-04 - val_loss: 3.4616e-04
# Epoch 68/100
# 15/15 [==============================] - 1s 53ms/step - loss: 3.7275e-04 - val_loss: 4.1987e-04
# Epoch 69/100
# 15/15 [==============================] - 1s 49ms/step - loss: 3.6853e-04 - val_loss: 4.4060e-04
# Epoch 70/100
# 15/15 [==============================] - 1s 50ms/step - loss: 3.6236e-04 - val_loss: 4.1274e-04
# Epoch 71/100
# 15/15 [==============================] - 1s 52ms/step - loss: 3.6359e-04 - val_loss: 4.1220e-04
# Epoch 72/100
# 15/15 [==============================] - 1s 51ms/step - loss: 3.6322e-04 - val_loss: 3.4652e-04
# Epoch 73/100
# 15/15 [==============================] - 1s 50ms/step - loss: 3.5897e-04 - val_loss: 4.2350e-04
# Epoch 74/100
# 15/15 [==============================] - 1s 52ms/step - loss: 3.6008e-04 - val_loss: 4.5683e-04
# Epoch 75/100
# 15/15 [==============================] - 1s 53ms/step - loss: 3.6482e-04 - val_loss: 5.4422e-04
# Epoch 76/100
# 15/15 [==============================] - 1s 54ms/step - loss: 3.6416e-04 - val_loss: 4.1930e-04
# Epoch 77/100
# 15/15 [==============================] - 1s 51ms/step - loss: 3.6647e-04 - val_loss: 3.2469e-04
# Epoch 78/100
# 15/15 [==============================] - 1s 53ms/step - loss: 3.6230e-04 - val_loss: 3.4151e-04
# Epoch 79/100
# 15/15 [==============================] - 1s 81ms/step - loss: 3.5240e-04 - val_loss: 3.5380e-04
# Epoch 80/100
# 15/15 [==============================] - 1s 84ms/step - loss: 3.5582e-04 - val_loss: 4.7232e-04
# Epoch 81/100
# 15/15 [==============================] - 1s 76ms/step - loss: 3.5308e-04 - val_loss: 4.4429e-04
# Epoch 82/100
# 15/15 [==============================] - 1s 51ms/step - loss: 3.5544e-04 - val_loss: 5.8658e-04
# Epoch 83/100
# 15/15 [==============================] - 1s 50ms/step - loss: 3.6302e-04 - val_loss: 3.3642e-04
# Epoch 84/100
# 15/15 [==============================] - 1s 50ms/step - loss: 3.5833e-04 - val_loss: 3.3069e-04
# Epoch 85/100
# 15/15 [==============================] - 1s 52ms/step - loss: 3.9235e-04 - val_loss: 3.0577e-04
# Epoch 86/100
# 15/15 [==============================] - 1s 52ms/step - loss: 3.5140e-04 - val_loss: 3.9385e-04
# Epoch 87/100
# 15/15 [==============================] - 1s 50ms/step - loss: 3.4743e-04 - val_loss: 3.9750e-04
# Epoch 88/100
# 15/15 [==============================] - 1s 50ms/step - loss: 3.5986e-04 - val_loss: 7.0323e-04
# Epoch 89/100
# 15/15 [==============================] - 1s 51ms/step - loss: 3.6170e-04 - val_loss: 4.2909e-04
# Epoch 90/100
# 15/15 [==============================] - 1s 50ms/step - loss: 3.4491e-04 - val_loss: 3.3414e-04
# Epoch 91/100
# 15/15 [==============================] - 1s 51ms/step - loss: 3.4262e-04 - val_loss: 3.7083e-04
# Epoch 92/100
# 15/15 [==============================] - 1s 51ms/step - loss: 3.5778e-04 - val_loss: 3.5199e-04
# Epoch 93/100
# 15/15 [==============================] - 1s 51ms/step - loss: 3.6416e-04 - val_loss: 8.3265e-04
# Epoch 94/100
# 15/15 [==============================] - 1s 65ms/step - loss: 3.6585e-04 - val_loss: 6.3246e-04
# Epoch 95/100
# 15/15 [==============================] - 1s 91ms/step - loss: 3.4210e-04 - val_loss: 3.7237e-04
# Epoch 96/100
# 15/15 [==============================] - 1s 84ms/step - loss: 3.3970e-04 - val_loss: 3.3064e-04
# Epoch 97/100
# 15/15 [==============================] - 1s 74ms/step - loss: 3.4119e-04 - val_loss: 7.1886e-04
# Epoch 98/100
# 15/15 [==============================] - 1s 52ms/step - loss: 3.5174e-04 - val_loss: 3.6694e-04
# Epoch 99/100
# 15/15 [==============================] - 1s 50ms/step - loss: 3.3983e-04 - val_loss: 4.0796e-04
# Epoch 100/100
# 15/15 [==============================] - 1s 50ms/step - loss: 3.3983e-04 - val_loss: 4.5781e-04

# %%
# Predict test data
train_predict = model.predict(X_train)
y_pred = model.predict(X_test)

# Normalize prediction data
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# Make predictions on the test set
y_pred_test = model.predict(X_test)

# Reshape test data and inverse transform if necessary
y_test = y_test.reshape(-1, 1)
y_test_inv = scaler.inverse_transform(y_test)

# Assuming y_pred_test is already in the shape required for inverse transform
y_pred_test = y_pred_test.reshape(-1, 1)
y_pred_test_inv = scaler.inverse_transform(y_pred_test)
# Out:
# 30/30 [==============================] - 1s 17ms/step
# 6/6 [==============================] - 0s 16ms/step
# 6/6 [==============================] - 0s 18ms/step

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_squared_log_error,mean_absolute_error
# Calculate MAPE for test set
test_MAPE = mean_absolute_percentage_error(y_test_inv, y_pred_test_inv)

# Calculate RMSE for test set
test_RMSE = mean_squared_error(y_test_inv, y_pred_test_inv, squared=False)

# Calculate MSLE for test set
test_MAE = mean_absolute_error(y_test_inv, y_pred_test_inv)

print('Test MAPE:', test_MAPE)
print('Test RMSE:', test_RMSE)
print('Test MAE:', test_MAE)
# Out:
# Test MAPE: 0.013658928566215431
# Test RMSE: 409.87995071785656
# Test MAE: 310.6021894483027

# %%
# Prediction function for a certain period of time
def predict_future_days(model, data, days, time_step):
    temp_input = list(data[-time_step:])
    lst_output = []

    for _ in range(days):
        x_input = np.array(temp_input[-time_step:])
        x_input = x_input.reshape(1, time_step, 1)
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())

    return lst_output

# Predict the next 30, 60, 90 days
future_30_days = predict_future_days(model, test_data['Close'].values, 30, time_step)
future_60_days = predict_future_days(model, test_data['Close'].values, 60, time_step)
future_90_days = predict_future_days(model, test_data['Close'].values, 90, time_step)

# Create new predicted date range
last_index_date = df_Close['Date'].iloc[-1]
predict_dates_30 = pd.date_range(start=last_index_date + pd.Timedelta(days=1), periods=30)
predict_dates_60 = pd.date_range(start=last_index_date + pd.Timedelta(days=1), periods=60)
predict_dates_90 = pd.date_range(start=last_index_date + pd.Timedelta(days=1), periods=90)

# %%
plt.figure(figsize=(12, 5))

plt.plot(df_Close['Date'][:train_size], scaler.inverse_transform(train_data[['Close']]))
plt.plot(df_Close['Date'][train_size:], scaler.inverse_transform(test_data[['Close']]))
plt.plot(df_Close['Date'][train_size + time_step:train_size + time_step + len(y_pred)], y_pred)
plt.plot(predict_dates_30, scaler.inverse_transform(future_30_days[:30]), linestyle='--')
plt.plot(predict_dates_60, scaler.inverse_transform(future_60_days[:60]), linestyle='--')
plt.plot(predict_dates_90, scaler.inverse_transform(future_90_days[:90]), linestyle='--')

plt.title("ACB's Stock Price Data With GRU Predictions")
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.legend(['Train', 'Test', 'Predict', 'Predict30days', 'Predict60days', 'Predict90days'])
plt.grid(True)
plt.show()
